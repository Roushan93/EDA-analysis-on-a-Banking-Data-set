LAG_DOCUMENT_11  FLAG_DOCUMENT_12  FLAG_DOCUMENT_13  FLAG_DOCUMENT_14  FLAG_DOCUMENT_15  FLAG_DOCUMENT_16  FLAG_DOCUMENT_17  FLAG_DOCUMENT_18  FLAG_DOCUMENT_19  FLAG_DOCUMENT_20  FLAG_DOCUMENT_21  AMT_REQ_CREDIT_BUREAU_HOUR  AMT_REQ_CREDIT_BUREAU_DAY  AMT_REQ_CREDIT_BUREAU_WEEK  AMT_REQ_CREDIT_BUREAU_MON  AMT_REQ_CREDIT_BUREAU_QRT  AMT_REQ_CREDIT_BUREAU_YEAR
# count              307511            307511            307511            307511            307511            307511            307511            307511            307511            307511            307511                      265992                     265992                      265992                     265992                     265992                      265992
# size               307511            307511            307511            307511            307511            307511            307511            307511            307511            307511            307511                      307511                     307511                      307511                     307511                     307511                      307511
# nunique                 2                 2                 2                 2                 2                 2                 2                 2                 2                 2                 2                           5                          9                           9                         24                         11                          25

# %% [markdown]
#  As we can see that there are columns which have less than 4 unique values which means that they are catagorical valuse.

# %% [markdown]
# ### Checking distribution of target column

# %%
defaulters=df1[df1.TARGET==1]
non_defaulters=df1[df1.TARGET==0]

# %%
sns.countplot(df1.TARGET)
plt.xlabel("TARGET Value")
plt.ylabel("Count of TARGET")
plt.title("Distribution of TARGET Variable")
plt.show()

# %% [markdown]
# we observe that there are far more loans that were repaid on time than loans that were not repaid. This is a imbalance distribution.

# %%
percentage_defaulters=(len(defaulters)*100)/len(df1)
percentage_nondefaulters=(len(non_defaulters)*100)/len(df1)
print(percentage_defaulters)
print(percentage_nondefaulters)
# Out:
# 8.072881945686495
# 91.92711805431351

# %% [markdown]
# Percentage of people who have paid their loan is: 91.93 %<br>
# Percentage of people who have NOT paid their loan is: 8.07 %

# %% [markdown]
# #### Ratio  :

# %%
print("ratio is : " ,round(len(non_defaulters)/len(defaulters),2))
# Out:
# ratio is :  11.39

# %% [markdown]
# ### Identifying missing values in each column

# %%
def meta_data(data):
    total = data.isnull().sum()
    percent = (round(100*(data.isnull().sum()/ len(data.index)),2))
    unique = data.nunique()
    datatypes = data.dtypes
    return pd.concat([total, percent, unique, datatypes], axis=1, keys=['Total', 'Percent', 'Unique', 'Data_Type']).sort_values(by="Percent", ascending=False)

# %%
app_meta_data=meta_data(df1)
app_meta_data.head(30)
# Out:
#                            Total  Percent  Unique Data_Type
# COMMONAREA_MEDI           214865    69.87    3202   float64
# COMMONAREA_AVG            214865    69.87    3181   float64
# COMMONAREA_MODE           214865    69.87    3128   float64
# NONLIVINGAPARTMENTS_MODE  213514    69.43     167   float64
# NONLIVINGAPARTMENTS_AVG   213514    69.43     386   float64
# NONLIVINGAPARTMENTS_MEDI  213514    69.43     214   float64
# FONDKAPREMONT_MODE        210295    68.39       4    object
# LIVINGAPARTMENTS_MODE     210199    68.35     736   float64
# LIVINGAPARTMENTS_AVG      210199    68.35    1868   float64
# LIVINGAPARTMENTS_MEDI     210199    68.35    1097   float64
# FLOORSMIN_AVG             208642    67.85     305   float64
# FLOORSMIN_MODE            208642    67.85      25   float64
# FLOORSMIN_MEDI            208642    67.85      47   float64
# YEARS_BUILD_MEDI          204488    66.50     151   float64
# YEARS_BUILD_MODE          204488    66.50     154   float64
# YEARS_BUILD_AVG           204488    66.50     149   float64
# OWN_CAR_AGE               202929    65.99      62   float64
# LANDAREA_MEDI             182590    59.38    3560   float64
# LANDAREA_MODE             182590    59.38    3563   float64
# LANDAREA_AVG              182590    59.38    3527   float64
# BASEMENTAREA_MEDI         179943    58.52    3772   float64
# BASEMENTAREA_AVG          179943    58.52    3780   float64
# BASEMENTAREA_MODE         179943    58.52    3841   float64
# EXT_SOURCE_1              173378    56.38  114584   float64
# NONLIVINGAREA_MODE        169682    55.18    3327   float64
000000                    0.000000                    0.000000                     0.000000                0.000000                0.000000                 0.000000  6.636171e-01                  2.000000                  0.000000                  2.000000                  0.000000             -274.000000         0.000000         1.000000         0.000000         0.000000         0.000000         0.000000         0.000000         0.000000          0.000000          0.000000          0.000000          0.000000          0.000000           0.00000          0.000000          0.000000          0.000000
# max    456255.000000       1.000000      19.000000      1.170000e+08  4.050000e+06  258025.500000     4.050000e+06                    0.072508   -7489.000000  365243.000000           0.000000         0.000000       1.000000        1.000000         1.000000          1.000000       1.000000       1.000000        20.000000              3.000000                     3.000000                23.000000                    1.000000                    1.000000                     1.000000                1.000000                1.000000                 1.000000  8.549997e-01                348.000000                 34.000000                344.000000                 24.000000                0.000000         1.000000         1.000000         1.000000         1.000000         1.000000         1.000000         1.000000         1.000000          1.000000          1.000000          1.000000          1.000000          1.000000           1.00000          1.000000          1.000000          1.000000
#
#        FLAG_DOCUMENT_19  FLAG_DOCUMENT_20  FLAG_DOCUMENT_21
# count     307511.000000     307511.000000     307511.000000
# mean           0.000595          0.000507          0.000335
# std            0.024387          0.022518          0.018299
# min            0.000000          0.000000          0.000000
# 25%            0.000000          0.000000          0.000000
# 50%            0.000000          0.000000          0.000000
# 75%            0.000000          0.000000          0.000000
# max            1.000000          1.000000          1.000000

# %%
df1.shape
# Out:
# (307511, 65)

# %% [markdown]
# #### we can observe that colum size reduced from 81 to 65.

# %%
low_missing=pd.DataFrame(app_meta_data[(app_meta_data.Percent>0)&(app_meta_data.Percent<13)])
low_missing
# Out:
#                           Total  Percent  Unique Data_Type
# NAME_TYPE_SUITE            1292     0.42       7    object
# DEF_30_CNT_SOCIAL_CIRCLE   1021     0.33      10   float64
# OBS_30_CNT_SOCIAL_CIRCLE   1021     0.33      33   float64
# OBS_60_CNT_SOCIAL_CIRCLE   1021     0.33      33   float64
# DEF_60_CNT_SOCIAL_CIRCLE   1021     0.33       9   float64
# EXT_SOURCE_2                660     0.21  119831   float64
# AMT_GOODS_PRICE             278     0.09    1002   float64

# %% [markdown]
#  OBS_30_CNT_SOCIAL_CIRCLE & related fields.<br>
#  AMT_GOODS_PRICE<br>
#  EXT_SOURCE_2<br>
# #### We should not add any additional info in missing values of these columns above as it would lead to noise and exaggeration.

# %% [markdown]
# NAME_TYPE_SUITE<br>
# #### we should leave empty values as it is or impute it with "Others A" or "Others B" depending on what they mean.

# %% [markdown]
# ### Let's take look at all the columns names for different data types

# %%
df1.select_dtypes('object').columns
# Out:
# Index(['NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'WEEKDAY_APPR_PROCESS_START', 'ORGANIZATION_TYPE'], dtype='object')

# %%
df1.select_dtypes('float64').columns
# Out:
# Index(['AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_ANNUITY', 'AMT_GOODS_PRICE', 'REGION_POPULATION_RELATIVE', 'DAYS_REGISTRATION', 'CNT_FAM_MEMBERS', 'EXT_SOURCE_2', 'OBS_30_CNT_SOCIAL_CIRCLE', 'DEF_30_CNT_SOCIAL_CIRCLE', 'OBS_60_CNT_SOCIAL_CIRCLE', 'DEF_60_CNT_SOCIAL_CIRCLE', 'DAYS_LAST_PHONE_CHANGE'], dtype='object')

# %%
df1.select_dtypes('int64').columns
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'CNT_CHILDREN', 'DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_ID_PUBLISH', 'FLAG_MOBIL', 'FLAG_EMP_PHONE', 'FLAG_WORK_PHONE', 'FLAG_CONT_MOBILE', 'FLAG_PHONE', 'FLAG_EMAIL', 'REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY', 'HOUR_APPR_PROCESS_START', 'REG_REGION_NOT_LIVE_REGION', 'REG_REGION_NOT_WORK_REGION', 'LIVE_REGION_NOT_WORK_REGION', 'REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY', 'FLAG_DOCUMENT_2', 'FLAG_DOCUMENT_3', 'FLAG_DOCUMENT_4', 'FLAG_DOCUMENT_5', 'FLAG_DOCUMENT_6', 'FLAG_DOCUMENT_7', 'FLAG_DOCUMENT_8', 'FLAG_DOCUMENT_9', 'FLAG_DOCUMENT_10', 'FLAG_DOCUMENT_11', 'FLAG_DOCUMENT_12', 'FLAG_DOCUMENT_13', 'FLAG_DOCUMENT_14', 'FLAG_DOCUMENT_15', 'FLAG_DOCUMENT_16', 'FLAG_DOCUMENT_17', 'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20', 'FLAG_DOCUMENT_21'], dtype='object')

# %% [markdown]
# ### A lot of int columns look like Flags, let check their unique values

# %%
df1.select_dtypes('int64').apply(pd.Series.nunique, axis = 0)
# Out:
# SK_ID_CURR                     307511
# TARGET                              2
# CNT_CHILDREN                       15
# DAYS_BIRTH                      17460
# DAYS_EMPLOYED                   12574
# DAYS_ID_PUBLISH                  6168
# FLAG_MOBIL                          2
# FLAG_EMP_PHONE                      2
# FLAG_WORK_PHONE                     2
# FLAG_CONT_MOBILE                    2
# FLAG_PHONE                          2
# FLAG_EMAIL                          2
# REGION_RATING_CLIENT                3
# REGION_RATING_CLIENT_W_CITY         3
# HOUR_APPR_PROCESS_START            24
# REG_REGION_NOT_LIVE_REGION          2
# REG_REGION_NOT_WORK_REGION          2
# LIVE_REGION_NOT_WORK_REGION         2
# REG_CITY_NOT_LIVE_CITY              2
# REG_CITY_NOT_WORK_CITY              2
# LIVE_CITY_NOT_WORK_CITY             2
# FLAG_DOCUMENT_2                     2
# FLAG_DOCUMENT_3                     2
# FLAG_DOCUMENT_4                     2
# FLAG_DOCUMENT_5                     2
# FLAG_DOCUMENT_6                     2
# FLAG_DOCUMENT_7                     2
# FLAG_DOCUMENT_8                     2
# FLAG_DOCUMENT_9                     2
# FLAG_DOCUMENT_10                    2
# FLAG_DOCUMENT_11                    2
# FLAG_DOCUMENT_12                    2
# FLAG_DOCUMENT_13                    2
# FLAG_DOCUMENT_14                    2
# FLAG_DOCUMENT_15                    2
# FLAG_DOCUMENT_16                    2
# FLAG_DOCUMENT_17                    2
# FLAG_DOCUMENT_18                    2
# FLAG_DOCUMENT_19                    2
# FLAG_DOCUMENT_20                    2
# FLAG_DOCUMENT_21                    2
# dtype: int64

# %% [markdown]
# Notice a lot of "int" columns have 2 unique values. These are flags or Flag type varibles. Which have no use in bivariate analysis. These can be converted to Yes/No values for categorical analysis.

# %%
#columns to convert
cols_to_convert=list(app_meta_data[(app_meta_data.Unique==2)&(app_meta_data.Data_Type=="int64")].index)

#function to conver columns
def convert_data(df1, cols_to_convert):
    for y in cols_to_convert:
        df1.loc[:,y].replace((0, 1), ('N', 'Y'), inplace=True)
    return df1

#calling the function for application_data
convert_data(df1, cols_to_convert)
df1.TARGET.replace(('N', 'Y'), (0, 1), inplace=True)
df1.dtypes.value_counts()
# Out:
# object     43
# float64    13
# int64       9
# dtype: int64

# %% [markdown]
# ## Univariate Analyis on Categorical Columns

# %%
defaulters=df1[df1.TARGET==1]

nondefaulters=df1[df1.TARGET==0]

# %% [markdown]
# ##### Getting a list of columns with dtype=object, to identify columns for categorical analysis

# %%
df1.select_dtypes('object').columns
# Out:
# Index(['NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'FLAG_MOBIL', 'FLAG_EMP_PHONE', 'FLAG_WORK_PHONE', 'FLAG_CONT_MOBILE', 'FLAG_PHONE', 'FLAG_EMAIL', 'WEEKDAY_APPR_PROCESS_START', 'REG_REGION_NOT_LIVE_REGION', 'REG_REGION_NOT_WORK_REGION', 'LIVE_REGION_NOT_WORK_REGION', 'REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY', 'ORGANIZATION_TYPE', 'FLAG_DOCUMENT_2', 'FLAG_DOCUMENT_3', 'FLAG_DOCUMENT_4', 'FLAG_DOCUMENT_5', 'FLAG_DOCUMENT_6', 'FLAG_DOCUMENT_7', 'FLAG_DOCUMENT_8', 'FLAG_DOCUMENT_9', 'FLAG_DOCUMENT_10', 'FLAG_DOCUMENT_11', 'FLAG_DOCUMENT_12', 'FLAG_DOCUMENT_13', 'FLAG_DOCUMENT_14', 'FLAG_DOCUMENT_15', 'FLAG_DOCUMENT_16', 'FLAG_DOCUMENT_17', 'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20', 'FLAG_DOCUMENT_21'], dtype='object')

# %%
def plot_charts(var, label_rotation,horizontal_layout):
    if(horizontal_layout):
        fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10,5))
    else:
        fig, (ax1, ax2) = plt.subplots(nrows=2, figsize=(15,20))
    
    s1=sns.countplot(ax=ax1,x=defaulters[var], data=defaulters, order= defaulters[var].value_counts().index,)
    ax1.set_title('Distribution of '+ '%s' %var +' for Defaulters', fontsize=10)
    ax1.set_xlabel('%s' %var)
    ax1.set_ylabel("Count of Loans")
    if(label_rotation):
        s1.set_xticklabels(s1.get_xticklabels(),rotation=90)
    s2=sns.countplot(ax=ax2,x=nondefaulters[var], data=nondefaulters, order= nondefaulters[var].value_counts().index,)
    if(label_rotation):
        s2.set_xticklabels(s2.get_xticklabels(),rotation=90)
    ax2.set_xlabel('%s' %var)
    ax2.set_ylabel("Count of Loans")
    ax2.set_title('Distribution of '+ '%s' %var +' for Non-Defaulters', fontsize=10)
    plt.show()

# %%
plot_charts('NAME_CONTRACT_TYPE', label_rotation=False,horizontal_layout=True)

# %% [markdown]
# We observe that the number of Cash loans is much higher than the number of Revolving loans for both Target = 0 and Target = 1

# %%
plot_charts('CODE_GENDER', label_rotation=False,horizontal_layout=True)

# %% [markdown]
# We observe that the number of Females taking loans is much higher than the number of Males for both Target = 0 and Target = 1

# %%
plot_charts('FLAG_OWN_REALTY', label_rotation=False,horizontal_layout=True)
plot_charts('FLAG_OWN_CAR', label_rotation=False,horizontal_layout=True)

# %% [markdown]
# We observe that the number of most people applying for loan do not own a car

# %%
plot_charts('REG_CITY_NOT_LIVE_CITY', label_rotation=False,horizontal_layout=True)
plot_charts('REG_CITY_NOT_WORK_CITY', label_rotation=True,horizontal_layout=True)

# %% [markdown]
# We observe that the Ratio of people whose Registration City is not the same as live city or work city is higher in case of defaulters are compared to defaulters.
#    It tells us that people who live or work in a city different than the registration city are more likely to have payment difficulties.

# %%
plot_charts('NAME_HOUSING_TYPE', label_rotation=True,horizontal_layout=True)

# %% [markdown]
# ### Observation:
#  &emsp; &emsp;Most people live in a House/Apartment<br>
#  &emsp; &emsp;Ratio of People who live With Parents is more for defaulter than non-defaulters.<br>
#  &emsp; &emsp;It tells us that applicant who live with<br>
#  &emsp; &emsp;parents have a higher chance of having payment difficulties.

# %%
plot_charts('NAME_FAMILY_STATUS', label_rotation=True,horizontal_layout=True)

# %% [markdown]
# Ratio of Single/Unmarried people is more in the left graph.<br>
#     Single/Unmarried people are more likely to have payment difficulties

# %%
plot_charts('NAME_EDUCATION_TYPE', label_rotation=True,horizontal_layout=True)

# %% [markdown]
# While the category with highest count remains same.<br>
#       &emsp;&emsp;This chart tells us that people with Academic Degree rarely take loans and are rarely defaulters. So they are potentially good customers.<br>
#       &emsp;&emsp;People with higher education are less likely to have payment difficulties. The Ratio is higher for non-defaulters than defaulters.

# %%
plot_charts('NAME_INCOME_TYPE', label_rotation=True,horizontal_layout=True)

# %% [markdown]
# Commercial associates, Pensioner, State Servants have a higher ratio to total in non-defaulters.

# %%
plot_charts('ORGANIZATION_TYPE', label_rotation=True,horizontal_layout=False)

# %%
plot_charts('FLAG_WORK_PHONE', label_rotation=True,horizontal_layout=True)

# %%
plot_charts('NAME_INCOME_TYPE', label_rotation=True,horizontal_layout=True)

# %% [markdown]
# ## Univariate & Bivariate Analyis on Numeric Columns

# %% [markdown]
# ### Getting a list of columns with dtype=object, to identify columns for analysis

# %%
df1.select_dtypes('float64').columns
# Out:
# Index(['AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_ANNUITY', 'AMT_GOODS_PRICE', 'REGION_POPULATION_RELATIVE', 'DAYS_REGISTRATION', 'CNT_FAM_MEMBERS', 'EXT_SOURCE_2', 'OBS_30_CNT_SOCIAL_CIRCLE', 'DEF_30_CNT_SOCIAL_CIRCLE', 'OBS_60_CNT_SOCIAL_CIRCLE', 'DEF_60_CNT_SOCIAL_CIRCLE', 'DAYS_LAST_PHONE_CHANGE'], dtype='object')

# %%
df1.select_dtypes('int64').columns
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'CNT_CHILDREN', 'DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_ID_PUBLISH', 'REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY', 'HOUR_APPR_PROCESS_START'], dtype='object')

# %% [markdown]
# ## Rmoving outliers:

# %%
def plot_boxhist(var):
    plt.figure(figsize=(15,5))
    plt.subplot(1, 2, 1)
    s=sns.boxplot(y=defaulters[var]);
    plt.title('Box Plot of '+ '%s' %var +' for Defaulters', fontsize=10)
    plt.xlabel('%s' %var)
    plt.ylabel("Count of Loans")
    plt.subplot(1, 2, 2)
    s=plt.hist(x=defaulters[var]);
    plt.xlabel('%s' %var)
    plt.ylabel("Count of Loans")
    plt.title('Histogram of '+ '%s' %var +' for Defaulters', fontsize=10)
plt.show()

# %%
plot_boxhist('AMT_INCOME_TOTAL')

# %% [markdown]
# We can see that there are some outliers and the graph looks like this to accomodate those outliers

# %%
#Removing all entries above 99 percentile
df1=df1[df1.AMT_INCOME_TOTAL<np.nanpercentile(df1['AMT_INCOME_TOTAL'], 99)]

#update dataframes
defaulters=df1[df1.TARGET==1] 
nondefaulters=df1[df1.TARGET==0]

plot_boxhist('AMT_INCOME_TOTAL')

# %% [markdown]
# This tell us that most people with payment have incomes in the lower range between 100000 to 200000 which some on the higher end some on the lower

# %%
plot_boxhist('AMT_CREDIT')

# %%
#Removing all entries above 99 percentile
df1=df1[df1.AMT_CREDIT<np.nanpercentile(df1['AMT_CREDIT'], 99)]

#update dataframes
defaulters=df1[df1.TARGET==1] 
nondefaulters=df1[df1.TARGET==0]

plot_boxhist('AMT_CREDIT')

# %% [markdown]
# we observe that the credit amount lies between 250000 to around 500000 for defaulters

# %%
plot_boxhist('AMT_ANNUITY')

# %%
#Removing all entries above 99 percentile
df1=df1[df1.AMT_ANNUITY<np.nanpercentile(df1['AMT_ANNUITY'], 90)]

#update dataframes
defaulters=df1[df1.TARGET==1] 
nondefaulters=df1[df1.TARGET==0]

plot_boxhist('AMT_ANNUITY')

# %%
#Deriving new metric Age from Days Birth
df1['AGE'] = df1['DAYS_BIRTH'] / -365
plt.hist(df1['AGE']);
plt.title('Histogram of age in years.');

# %% [markdown]
# #### Age seems to be fairly distributed

# %%
sns.boxplot(y=df1['DAYS_EMPLOYED']);
plt.title('Length of days employed before loan.');

# %%
df1['DAYS_EMPLOYED'].describe()
# Out:
# count    270624.000000
# mean      66967.610744
# std      143809.691359
# min      -17912.000000
# 25%       -2690.000000
# 50%       -1165.000000
# 75%        -258.000000
# max      365243.000000
# Name: DAYS_EMPLOYED, dtype: float64

# %% [markdown]
# ####  There is an outlier here. The max value is 365243 days which is not practically possible. This might be an error and we can replace this value with null

# %%
#Deriving variable "Years Employed" from days employed
df1['YEARS_EMPLOYED'] = (df1['DAYS_EMPLOYED']/-365)

#update dataframes
defaulters=df1[df1.TARGET==1] 
nondefaulters=df1[df1.TARGET==0]

# %%
plot_boxhist('YEARS_EMPLOYED')

# %% [markdown]
# #### A large number of entries have 0 which means, a lot of people don't work.

# %%
df1.groupby(['NAME_INCOME_TYPE']).agg({'YEARS_EMPLOYED': ['mean', 'median', 'count', 'max'], 'AGE': ['median']})
# Out:
#                      YEARS_EMPLOYED                                          AGE
#                                mean       median   count          max     median
# NAME_INCOME_TYPE
# Businessman                5.544292     4.838356       3     7.175342  52.487671
# Commercial associate       5.730061     4.010959   58866    48.071233  39.413699
# Maternity leave            6.453425     6.260274       4     9.942466  37.649315
# Pensioner              -1000.466985 -1000.665753   51025    35.246575  60.506849
# State servant              9.276139     7.008219   18445    48.172603  40.482192
# Student                    6.765582     4.954795      16    21.931507  41.215068
# Unemployed             -1000.665753 -1000.665753      19 -1000.665753  46.832877
# Working                    6.377079     4.347945  142246    49.073973  39.679452

# %% [markdown]
# #### We see that Pensioners comprise a lot of non-working people, which is normal. Working people seemed to have worked for many years.

# %%
df1.groupby(['NAME_EDUCATION_TYPE', 'NAME_INCOME_TYPE']).agg({'AMT_INCOME_TOTAL': ['mean', 'median', 'count', 'max']})
# Out:
#                                                    AMT_INCOME_TOTAL
#                                                                mean    median   count       max
# NAME_EDUCATION_TYPE           NAME_INCOME_TYPE
# Academic degree               Commercial associate    230700.000000  225000.0      30  450000.0
#                               Pensioner               163620.000000  135000.0      20  315000.0
#                               State servant           230062.500000  198000.0      16  450000.0
#                               Working                 206100.000000  180000.0      60  450000.0
# Higher education              Businessman             195000.000000  180000.0       3  225000.0
#                               Commercial associate    201003.446086  180000.0   17990  468000.0
#                               Maternity leave         112500.000000  112500.0       2  135000.0
#                               Pensioner               151193.659642  135000.0    6893  450000.0
#                               State servant           183217.739153  171000.0    7065  450000.0
#                               Student                 164700.000000  171000.0       5  225000.0
#                               Unemployed              204300.000000  225000.0       5  337500.0
#                               Working                 173712.264383  157500.0   28213  463500.0
# Incomplete higher             Commercial associate    182876.896934  164623.5    2838  468823.5
#                               Pensioner               141442.696352  135000.0     466  450000.0
#                               State servant           165287.840000  157500.0     675  450000.0
#                               Student                 157500.000000  157500.0       1  157500.0
#                               Unemployed              126000.000000   63000.0       3  270000.0
#                               Working                 158877.631087  135000.0    4970  450000.0
# Lower secondary               Commercial associate    157017.140515  135000.0     427  450000.0
#                               Pensioner               103467.097166   90000.0    1482  360000.0
#                               State servant           135703.125000  112500.0      96  427500.0
#                               Working                 134821.250000  126000.0    1620  450000.0
# Secondary / secondary special Commercial associate    167227.792605  157500.0   37581  463500.0
#                               Maternity leave          58500.000000   58500.0       2   67500.0
#                               Pensioner               124717.747472  112500.0   42164  459000.0
#                               State servant           149828.084681  135000.0   10593  468000.0
#                               Student                 130050.000000  128250.0      10  180000.0
#                               Unemployed               70322.727273   63000.0      11  135000.0
#                               Working                 145718.602949  135000.0  107383  468000.0

# %% [markdown]
# #### We can see that most of the loans are taken by working people with secondary education.

# %% [markdown]
# ## Binning of Continuous Variables

# %%
df1['AMT_INCOME_TOTAL'].describe()
# Out:
# count    270624.000000
# mean     153723.159193
# std       70918.773625
# min       25650.000000
# 25%      108000.000000
# 50%      135000.000000
# 75%      180000.000000
# max      468823.500000
# Name: AMT_INCOME_TOTAL, dtype: float64

# %%
defaulters.loc[:,'INCOME_BRACKET']=pd.qcut(df1.loc[:,'AMT_INCOME_TOTAL'],q=[0,0.10,0.35,0.50,0.90,1], labels=['Very_low','Low','Medium','High','Very_high'])
nondefaulters.loc[:,'INCOME_BRACKET']=pd.qcut(df1.loc[:,'AMT_INCOME_TOTAL'],q=[0,0.10,0.35,0.50,0.90,1], labels=['Very_low','Low','Medium','High','Very_high'])

# %% [markdown]
# ## Analysis of Continuous variables for TARGET=1 and TARGET=0

# %%
plot_charts('INCOME_BRACKET', label_rotation=True,horizontal_layout=True)

# %% [markdown]
# #### A large number of defaulters have very Low rating, while a large number of non-defaulters have a high rating.

# %%
defaulters.loc[:,'Rating']=pd.cut(df1.loc[:,'EXT_SOURCE_2'],[0,0.10,0.35,0.50,0.80,1], labels=['Very_low','Low','Medium','High','Very_high'])
nondefaulters.loc[:,'Rating']=pd.cut(df1.loc[:,'EXT_SOURCE_2'],[0,0.10,0.35,0.50,0.80,1], labels=['Very_low','Low','Medium','High','Very_high'])

# %%
plot_charts('Rating', label_rotation=True,horizontal_layout=True)

# %% [markdown]
# ####  A large number of defaulters have Low rating, while a large number of non-defaulters have a high rating.

# %%
defaulters.loc[:,'AMT_ANNUITY_BINS']=pd.qcut(df1.loc[:,'AMT_ANNUITY'], [0,0.30,0.50,0.85,0.1], labels=['Low','Medium','High','Very_High'])
nondefaulters.loc[:,'AMT_ANNUITY_BINS']=pd.qcut(df1.loc[:,'AMT_ANNUITY'], [0,0.30,0.50,0.85,1], labels=['Low','Medium','High','Very_High'])

# %%
plot_charts('AMT_ANNUITY_BINS', label_rotation=False,horizontal_layout=True)

# %% [markdown]
# #### maxinum number of defaulters have Low_annuity Values, while maximum number of non-defaulters have high annuity

# %%
age_data = df1.loc[:,['TARGET', 'DAYS_BIRTH']]
age_data.loc[:,'YEARS_BIRTH'] = df1.loc[:,'DAYS_BIRTH']/ -365
# Bin the age data
age_data.loc[:,'YEARS_BINNED'] = pd.cut(age_data.loc[:,'YEARS_BIRTH'], bins = np.linspace(20, 70, num = 11))
age_data.head(10)
# Out:
#    TARGET  DAYS_BIRTH  YEARS_BIRTH  YEARS_BINNED
# 0       1       -9461    25.920548  (25.0, 30.0]
# 1       0      -16765    45.931507  (45.0, 50.0]
# 2       0      -19046    52.180822  (50.0, 55.0]
# 3       0      -19005    52.068493  (50.0, 55.0]
# 4       0      -19932    54.608219  (50.0, 55.0]
# 5       0      -16941    46.413699  (45.0, 50.0]
# 6       0      -13778    37.747945  (35.0, 40.0]
# 7       0      -18850    51.643836  (50.0, 55.0]
# 8       0      -20099    55.065753  (55.0, 60.0]
# 9       0      -14469    39.641096  (35.0, 40.0]

# %%
age_groups  = age_data.groupby('YEARS_BINNED').mean()
age_groups
# Out:
#                 TARGET    DAYS_BIRTH  YEARS_BIRTH
# YEARS_BINNED
# (20.0, 25.0]  0.123634  -8526.531171    23.360359
# (25.0, 30.0]  0.114012 -10149.579304    27.807067
# (30.0, 35.0]  0.106704 -11852.848779    32.473558
# (35.0, 40.0]  0.092880 -13705.912891    37.550446
# (40.0, 45.0]  0.082295 -15495.702723    42.453980
# (45.0, 50.0]  0.077458 -17326.817002    47.470732
# (50.0, 55.0]  0.069519 -19200.394964    52.603822
# (55.0, 60.0]  0.057357 -20987.323723    57.499517
# (60.0, 65.0]  0.054386 -22782.049911    62.416575
# (65.0, 70.0]  0.037478 -24297.506142    66.568510

# %%
plt.figure(figsize = (8, 8))

# Graph the age bins and the average of the target as a bar plot
plt.bar(age_groups.index.astype(str), 100 * age_groups['TARGET'])

# Plot labeling
plt.xticks(rotation = 75); plt.xlabel('Age Group (years)'); plt.ylabel('Failure to Repay (%)')
plt.title('Failure to Repay by Age Group');

# %% [markdown]
# #### Maximum Failure to Repay is in Age Group 20-25.

# %% [markdown]
# ## Bi-Variate Analysis of Variables

# %%
#selecting columns for correlation, removing cols for floor and house ec

cols=[ 'EXT_SOURCE_2',
       'AMT_GOODS_PRICE', 'AMT_ANNUITY', 'CNT_FAM_MEMBERS',
       'DAYS_LAST_PHONE_CHANGE', 'AMT_CREDIT', 'AMT_INCOME_TOTAL',
       'DAYS_REGISTRATION', 'REGION_POPULATION_RELATIVE','CNT_CHILDREN', 'HOUR_APPR_PROCESS_START',
       'REGION_RATING_CLIENT_W_CITY', 'REGION_RATING_CLIENT',
       'DAYS_ID_PUBLISH', 'DAYS_EMPLOYED', 'DAYS_BIRTH']

# %%
defaulters_1=defaulters[cols]
defaulters_correlation = defaulters_1.corr()
round(defaulters_correlation, 3)
# Out:
#                              EXT_SOURCE_2  AMT_GOODS_PRICE  AMT_ANNUITY  CNT_FAM_MEMBERS  DAYS_LAST_PHONE_CHANGE  AMT_CREDIT  AMT_INCOME_TOTAL  DAYS_REGISTRATION  REGION_POPULATION_RELATIVE  CNT_CHILDREN  HOUR_APPR_PROCESS_START  REGION_RATING_CLIENT_W_CITY  REGION_RATING_CLIENT  DAYS_ID_PUBLISH  DAYS_EMPLOYED  DAYS_BIRTH
# EXT_SOURCE_2                        1.000            0.107        0.081            0.000                  -0.207       0.096             0.124             -0.068                       0.157        -0.013                    0.130                       -0.236                -0.238           -0.061          0.004      -0.109
# AMT_GOODS_PRICE                     0.107            1.000        0.741            0.048                  -0.114       0.978             0.277             -0.038                       0.060        -0.008                    0.039                       -0.053                -0.047           -0.056          0.016      -0.144
# AMT_ANNUITY                         0.081            0.741        1.000            0.075                  -0.071       0.757             0.341              0.031                       0.032         0.031                    0.021                       -0.044                -0.034           -0.014         -0.080      -0.016
# CNT_FAM_MEMBERS                     0.000            0.048        0.075            1.000                  -0.012       0.052            -0.002              0.146                      -0.033         0.884                   -0.026                        0.052                 0.045           -0.025         -0.192       0.208
# DAYS_LAST_PHONE_CHANGE             -0.207           -0.114       -0.071           -0.012                   1.000      -0.104            -0.082              0.070                      -0.055         0.010                   -0.021                        0.018                 0.017            0.128          0.001       0.111
# AMT_CREDIT                          0.096            0.978        0.757            0.052                  -0.104       1.000             0.279             -0.038                       0.053         0.000                    0.025                       -0.047                -0.039           -0.052          0.011      -0.143
# AMT_INCOME_TOTAL                    0.124            0.277        0.341           -0.002                  -0.082       0.279             1.000              0.033                       0.092        -0.007                    0.077                       -0.161                -0.148           -0.002         -0.118       0.004
# DAYS_REGISTRATION                  -0.068           -0.038        0.031            0.146                   0.070      -0.038             0.033              1.000                      -0.055         0.149                   -0.031                        0.105                 0.107            0.101         -0.195       0.293
# REGION_POPULATION_RELATIVE          0.157            0.060        0.032           -0.033                  -0.055       0.053             0.092             -0.055                       1.000        -0.034                    0.130                       -0.421                -0.417           -0.011          0.018      -0.051
# CNT_CHILDREN                       -0.013           -0.008        0.031            0.884                   0.010       0.000            -0.007              0.149                      -0.034         1.000                   -0.020                        0.045                 0.041           -0.028         -0.196       0.261
# HOUR_APPR_PROCESS_START             0.130            0.039        0.021           -0.026                  -0.021       0.025             0.077             -0.031                       0.130        -0.020                    1.000                       -0.275                -0.292            0.024         -0.059       0.065
# REGION_RATING_CLIENT_W_CITY        -0.236           -0.053       -0.044            0.052                   0.018      -0.047            -0.161              0.105                      -0.421         0.045                   -0.275                        1.000                 0.961            0.001         -0.003       0.034
# REGION_RATING_CLIENT               -0.238           -0.047       -0.034            0.045                   0.017      -0.039            -0.148              0.107                      -0.417         0.041                   -0.292                        0.961                 1.000            0.004         -0.001       0.036
# DAYS_ID_PUBLISH                    -0.061           -0.056       -0.014           -0.025                   0.128      -0.052            -0.002              0.101                      -0.011        -0.028                    0.024                        0.001                 0.004            1.000         -0.233       0.262
# DAYS_EMPLOYED                       0.004            0.016       -0.080           -0.192                   0.001       0.011            -0.118             -0.195                       0.018        -0.196                   -0.059                       -0.003                -0.001           -0.233          1.000      -0.584
# DAYS_BIRTH                         -0.109           -0.144       -0.016            0.208                   0.111      -0.143             0.004              0.293                      -0.051         0.261                    0.065                        0.034                 0.036            0.262         -0.584       1.000

# %%
defaulters_correlation.head(10).index
# Out:
# Index(['EXT_SOURCE_2', 'AMT_GOODS_PRICE', 'AMT_ANNUITY', 'CNT_FAM_MEMBERS', 'DAYS_LAST_PHONE_CHANGE', 'AMT_CREDIT', 'AMT_INCOME_TOTAL', 'DAYS_REGISTRATION', 'REGION_POPULATION_RELATIVE', 'CNT_CHILDREN'], dtype='object')

# %%
c1=defaulters_correlation.unstack()
c1.sort_values(ascending=False).drop_duplicates().head(10)
# Out:
# DAYS_BIRTH            DAYS_BIRTH                     1.000000
# AMT_GOODS_PRICE       AMT_CREDIT                     0.978079
# REGION_RATING_CLIENT  REGION_RATING_CLIENT_W_CITY    0.961097
# CNT_FAM_MEMBERS       CNT_CHILDREN                   0.883502
# AMT_ANNUITY           AMT_CREDIT                     0.756598
# AMT_GOODS_PRICE       AMT_ANNUITY                    0.741243
# AMT_ANNUITY           AMT_INCOME_TOTAL               0.340531
# DAYS_BIRTH            DAYS_REGISTRATION              0.292698
# AMT_INCOME_TOTAL      AMT_CREDIT                     0.278920
#                       AMT_GOODS_PRICE                0.276736
# dtype: float64

# %%
c1.sort_values(ascending=False).drop_duplicates().tail(10)
# Out:
# DAYS_EMPLOYED                CNT_CHILDREN                  -0.196037
# DAYS_LAST_PHONE_CHANGE       EXT_SOURCE_2                  -0.207268
# DAYS_EMPLOYED                DAYS_ID_PUBLISH               -0.233344
# REGION_RATING_CLIENT_W_CITY  EXT_SOURCE_2                  -0.236492
# EXT_SOURCE_2                 REGION_RATING_CLIENT          -0.238035
# HOUR_APPR_PROCESS_START      REGION_RATING_CLIENT_W_CITY   -0.275065
# REGION_RATING_CLIENT         HOUR_APPR_PROCESS_START       -0.291574
# REGION_POPULATION_RELATIVE   REGION_RATING_CLIENT          -0.417374
#                              REGION_RATING_CLIENT_W_CITY   -0.421099
# DAYS_BIRTH                   DAYS_EMPLOYED                 -0.584493
# dtype: float64

# %%
#figure size
plt.figure(figsize=(30,20))
#heatmap
sns.heatmap(defaulters_correlation, cmap="YlGnBu", annot=True)
plt.show()

# %% [markdown]
# ### 5 most positive correlations:

# %% [markdown]
# DAYS_BIRTH             -    DAYS_BIRTH<br>
# AMT_GOODS_PRICE        -    AMT_CREDIT
# REGION_RATING_CLIENT   -    REGION_RATING_CLIENT_W_CITY
# CNT_FAM_MEMBERS        -    CNT_CHILDREN
# AMT_ANNUITY            -    AMT_CREDIT

# %% [markdown]
# ### 5 most negative correlations

# %% [markdown]
# DAYS_EMPLOYED                CNT_CHILDREN
# DAYS_LAST_PHONE_CHANGE       EXT_SOURCE_2
# DAYS_EMPLOYED                DAYS_ID_PUBLISH
# REGION_RATING_CLIENT_W_CITY  EXT_SOURCE_2
# EXT_SOURCE_2                 REGION_RATING_CLIENT

# %%
nondefaulters_1=nondefaulters[cols]
nondefaulters_correlation = nondefaulters_1.corr()
round(nondefaulters_correlation, 3)
# Out:
#                              EXT_SOURCE_2  AMT_GOODS_PRICE  AMT_ANNUITY  CNT_FAM_MEMBERS  DAYS_LAST_PHONE_CHANGE  AMT_CREDIT  AMT_INCOME_TOTAL  DAYS_REGISTRATION  REGION_POPULATION_RELATIVE  CNT_CHILDREN  HOUR_APPR_PROCESS_START  REGION_RATING_CLIENT_W_CITY  REGION_RATING_CLIENT  DAYS_ID_PUBLISH  DAYS_EMPLOYED  DAYS_BIRTH
# EXT_SOURCE_2                        1.000            0.102        0.088           -0.003                  -0.189       0.094             0.146             -0.053                       0.180        -0.015                    0.152                       -0.271                -0.275           -0.042         -0.026      -0.078
# AMT_GOODS_PRICE                     0.102            1.000        0.777            0.057                  -0.077       0.982             0.311              0.005                       0.051        -0.003                    0.050                       -0.054                -0.050           -0.005         -0.062      -0.049
# AMT_ANNUITY                         0.088            0.777        1.000            0.074                  -0.067       0.788             0.374              0.032                       0.059         0.021                    0.036                       -0.082                -0.073            0.017         -0.106       0.015
# CNT_FAM_MEMBERS                    -0.003            0.057        0.074            1.000                  -0.030       0.058             0.033              0.179                      -0.025         0.876                   -0.010                        0.032                 0.030           -0.017         -0.243       0.290
# DAYS_LAST_PHONE_CHANGE             -0.189           -0.077       -0.067           -0.030                   1.000      -0.074            -0.058              0.052                      -0.039        -0.009                   -0.014                        0.020                 0.021            0.087          0.026       0.075
# AMT_CREDIT                          0.094            0.982        0.788            0.058                  -0.074       1.000             0.310              0.002                       0.047         0.001                    0.040                       -0.054                -0.049           -0.003         -0.064      -0.051
# AMT_INCOME_TOTAL                    0.146            0.311        0.374            0.033                  -0.058       0.310             1.000              0.076                       0.153         0.031                    0.084                       -0.207                -0.189            0.033         -0.181       0.092
# DAYS_REGISTRATION                  -0.053            0.005        0.032            0.179                   0.052       0.002             0.076              1.000                      -0.050         0.190                   -0.008                        0.073                 0.078            0.103         -0.216       0.337
# REGION_POPULATION_RELATIVE          0.180            0.051        0.059           -0.025                  -0.039       0.047             0.153             -0.050                       1.000        -0.025                    0.153                       -0.503                -0.504           -0.003         -0.002      -0.027
# CNT_CHILDREN                       -0.015           -0.003        0.021            0.876                  -0.009       0.001             0.031              0.190                      -0.025         1.000                   -0.004                        0.023                 0.024           -0.026         -0.250       0.340
# HOUR_APPR_PROCESS_START             0.152            0.050        0.036           -0.010                  -0.014       0.040             0.084             -0.008                       0.153        -0.004                    1.000                       -0.256                -0.276            0.038         -0.099       0.101
# REGION_RATING_CLIENT_W_CITY        -0.271           -0.054       -0.082            0.032                   0.020      -0.054            -0.207              0.073                      -0.503         0.023                   -0.256                        1.000                 0.952           -0.010          0.034       0.002
# REGION_RATING_CLIENT               -0.275           -0.050       -0.073            0.030                   0.021      -0.049            -0.189              0.078                      -0.504         0.024                   -0.276                        0.952                 1.000           -0.008          0.032       0.004
# DAYS_ID_PUBLISH                    -0.042           -0.005        0.017           -0.017                   0.087      -0.003             0.033              0.103                      -0.003        -0.026                    0.038                       -0.010                -0.008            1.000         -0.285       0.288
# DAYS_EMPLOYED                      -0.026           -0.062       -0.106           -0.243                   0.026      -0.064            -0.181             -0.216                      -0.002        -0.250                   -0.099                        0.034                 0.032           -0.285          1.000      -0.631
# DAYS_BIRTH                         -0.078           -0.049        0.015            0.290                   0.075      -0.051             0.092              0.337                      -0.027         0.340                    0.101                        0.002                 0.004            0.288         -0.631       1.000

# %%
nondefaulters_correlation.head(10).index
# Out:
# Index(['EXT_SOURCE_2', 'AMT_GOODS_PRICE', 'AMT_ANNUITY', 'CNT_FAM_MEMBERS', 'DAYS_LAST_PHONE_CHANGE', 'AMT_CREDIT', 'AMT_INCOME_TOTAL', 'DAYS_REGISTRATION', 'REGION_POPULATION_RELATIVE', 'CNT_CHILDREN'], dtype='object')

# %%
c2=nondefaulters_correlation.unstack()

# %%
c2.sort_values(ascending=False).drop_duplicates().head(10)
# Out:
# DAYS_BIRTH            DAYS_BIRTH                     1.000000
# AMT_GOODS_PRICE       AMT_CREDIT                     0.982300
# REGION_RATING_CLIENT  REGION_RATING_CLIENT_W_CITY    0.951842
# CNT_FAM_MEMBERS       CNT_CHILDREN                   0.875910
# AMT_ANNUITY           AMT_CREDIT                     0.787971
# AMT_GOODS_PRICE       AMT_ANNUITY                    0.777270
# AMT_ANNUITY           AMT_INCOME_TOTAL               0.374166
# DAYS_BIRTH            CNT_CHILDREN                   0.340493
#                       DAYS_REGISTRATION              0.336957
# AMT_INCOME_TOTAL      AMT_GOODS_PRICE                0.310728
# dtype: float64

# %%
c2.sort_values(ascending=False).drop_duplicates().tail(10)
# Out:
# DAYS_EMPLOYED                CNT_FAM_MEMBERS              -0.243348
# CNT_CHILDREN                 DAYS_EMPLOYED                -0.250478
# REGION_RATING_CLIENT_W_CITY  HOUR_APPR_PROCESS_START      -0.256174
#                              EXT_SOURCE_2                 -0.270836
# REGION_RATING_CLIENT         EXT_SOURCE_2                 -0.275245
#                              HOUR_APPR_PROCESS_START      -0.276454
# DAYS_ID_PUBLISH              DAYS_EMPLOYED                -0.285225
# REGION_RATING_CLIENT_W_CITY  REGION_POPULATION_RELATIVE   -0.502861
# REGION_RATING_CLIENT         REGION_POPULATION_RELATIVE   -0.503572
# DAYS_BIRTH                   DAYS_EMPLOYED                -0.631296
# dtype: float64

# %% [markdown]
# ### Heat Map

# %%
plt.figure(figsize=(30,20))
sns.heatmap(nondefaulters_correlation, cmap="YlGnBu", annot=True)
plt.show()

# %% [markdown]
# # Analysis of Previous Application Dataset

# %%
df2.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE WEEKDAY_APPR_PROCESS_START  HOUR_APPR_PROCESS_START FLAG_LAST_APPL_PER_CONTRACT  NFLAG_LAST_APPL_IN_DAY  RATE_DOWN_PAYMENT  RATE_INTEREST_PRIMARY  RATE_INTEREST_PRIVILEGED NAME_CASH_LOAN_PURPOSE NAME_CONTRACT_STATUS  DAYS_DECISION      NAME_PAYMENT_TYPE CODE_REJECT_REASON  NAME_TYPE_SUITE NAME_CLIENT_TYPE NAME_GOODS_CATEGORY NAME_PORTFOLIO NAME_PRODUCT_TYPE             CHANNEL_TYPE  SELLERPLACE_AREA NAME_SELLER_INDUSTRY  CNT_PAYMENT NAME_YIELD_GROUP       PRODUCT_COMBINATION  DAYS_FIRST_DRAWING  DAYS_FIRST_DUE  DAYS_LAST_DUE_1ST_VERSION  DAYS_LAST_DUE  DAYS_TERMINATION  NFLAG_INSURED_ON_APPROVAL
# 0     2030495      271877     Consumer loans     1730.430          17145.0     17145.0               0.0          17145.0                   SATURDAY                       15                           Y                       1                0.0               0.182832                  0.867336                    XAP             Approved            -73  Cash through the bank                XAP              NaN         Repeater              Mobile            POS               XNA             Country-wide                35         Connectivity         12.0           middle  POS mobile with interest            365243.0           -42.0                      300.0          -42.0             -37.0                        0.0
# 1     2802425      108129         Cash loans    25188.615         607500.0    679671.0               NaN         607500.0                   THURSDAY                       11                           Y                       1                NaN                    NaN                       NaN                    XNA             Approved           -164                    XNA                XAP    Unaccompanied         Repeater                 XNA           Cash            x-sell           Contact center                -1                  XNA         36.0       low_action          Cash X-Sell: low            365243.0          -134.0                      916.0       365243.0          365243.0                        1.0
# 2     2523466      122040         Cash loans    15060.735         112500.0    136444.5               NaN         112500.0                    TUESDAY                       11                           Y                       1                NaN                    NaN                       NaN                    XNA             Approved           -301  Cash through the bank                XAP  Spouse, partner         Repeater                 XNA           Cash            x-sell  Credit and cash offices                -1                  XNA         12.0             high         Cash X-Sell: high            365243.0          -271.0                       59.0       365243.0          365243.0                        1.0
# 3     2819243      176158         Cash loans    47041.335         450000.0    470790.0               NaN         450000.0                     MONDAY                        7                           Y                       1                NaN                    NaN                       NaN                    XNA             Approved           -512  Cash through the bank                XAP              NaN         Repeater                 XNA           Cash            x-sell  Credit and cash offices                -1                  XNA         12.0           middle       Cash X-Sell: middle            365243.0          -482.0                     -152.0         -182.0            -177.0                        1.0
# 4     1784265      202054         Cash loans    31924.395         337500.0    404055.0               NaN         337500.0                   THURSDAY                        9                           Y                       1                NaN                    NaN                       NaN                Repairs              Refused           -781  Cash through the bank                 HC              NaN         Repeater                 XNA           Cash           walk-in  Credit and cash offices                -1                  XNA         24.0             high         Cash Street: high                 NaN             NaN                        NaN            NaN               NaN                        NaN

# %%
df2.shape
# Out:
# (1670214, 37)

# %% [markdown]
# This dataset for application data has:<br>
# 1670214 rows<br>
# 37 columns

# %%
df2.dtypes.value_counts()
# Out:
# object     16
# float64    15
# int64       6
# dtype: int64

# %%
df2.dtypes.value_counts()
# Out:
# object     16
# float64    15
# int64       6
# dtype: int64

# %% [markdown]
# We can see that there are:</font>
#
# 65 columns with dtype=float64</font>
# 41 columns with dtype=int64</font>
# 16 columns with dtype=object

# %%
df2.columns
# Out:
# Index(['SK_ID_PREV', 'SK_ID_CURR', 'NAME_CONTRACT_TYPE', 'AMT_ANNUITY', 'AMT_APPLICATION', 'AMT_CREDIT', 'AMT_DOWN_PAYMENT', 'AMT_GOODS_PRICE', 'WEEKDAY_APPR_PROCESS_START', 'HOUR_APPR_PROCESS_START', 'FLAG_LAST_APPL_PER_CONTRACT', 'NFLAG_LAST_APPL_IN_DAY', 'RATE_DOWN_PAYMENT', 'RATE_INTEREST_PRIMARY', 'RATE_INTEREST_PRIVILEGED', 'NAME_CASH_LOAN_PURPOSE', 'NAME_CONTRACT_STATUS', 'DAYS_DECISION', 'NAME_PAYMENT_TYPE', 'CODE_REJECT_REASON', 'NAME_TYPE_SUITE', 'NAME_CLIENT_TYPE', 'NAME_GOODS_CATEGORY', 'NAME_PORTFOLIO', 'NAME_PRODUCT_TYPE', 'CHANNEL_TYPE', 'SELLERPLACE_AREA', 'NAME_SELLER_INDUSTRY', 'CNT_PAYMENT', 'NAME_YIELD_GROUP', 'PRODUCT_COMBINATION', 'DAYS_FIRST_DRAWING', 'DAYS_FIRST_DUE', 'DAYS_LAST_DUE_1ST_VERSION', 'DAYS_LAST_DUE', 'DAYS_TERMINATION', 'NFLAG_INSURED_ON_APPROVAL'], dtype='object')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1670214 entries, 0 to 1670213
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   SK_ID_PREV                   1670214 non-null  int64
#  1   SK_ID_CURR                   1670214 non-null  int64
#  2   NAME_CONTRACT_TYPE           1670214 non-null  object
#  3   AMT_ANNUITY                  1297979 non-null  float64
#  4   AMT_APPLICATION              1670214 non-null  float64
#  5   AMT_CREDIT                   1670213 non-null  float64
#  6   AMT_DOWN_PAYMENT             774370 non-null   float64
#  7   AMT_GOODS_PRICE              1284699 non-null  float64
#  8   WEEKDAY_APPR_PROCESS_START   1670214 non-null  object
#  9   HOUR_APPR_PROCESS_START      1670214 non-null  int64
#  10  FLAG_LAST_APPL_PER_CONTRACT  1670214 non-null  object
#  11  NFLAG_LAST_APPL_IN_DAY       1670214 non-null  int64
#  12  RATE_DOWN_PAYMENT            774370 non-null   float64
#  13  RATE_INTEREST_PRIMARY        5951 non-null     float64
#  14  RATE_INTEREST_PRIVILEGED     5951 non-null     float64
#  15  NAME_CASH_LOAN_PURPOSE       1670214 non-null  object
#  16  NAME_CONTRACT_STATUS         1670214 non-null  object
#  17  DAYS_DECISION                1670214 non-null  int64
#  18  NAME_PAYMENT_TYPE            1670214 non-null  object
#  19  CODE_REJECT_REASON           1670214 non-null  object
#  20  NAME_TYPE_SUITE              849809 non-null   object
#  21  NAME_CLIENT_TYPE             1670214 non-null  object
#  22  NAME_GOODS_CATEGORY          1670214 non-null  object
#  23  NAME_PORTFOLIO               1670214 non-null  object
#  24  NAME_PRODUCT_TYPE            1670214 non-null  object
#  25  CHANNEL_TYPE                 1670214 non-null  object
#  26  SELLERPLACE_AREA             1670214 non-null  int64
#  27  NAME_SELLER_INDUSTRY         1670214 non-null  object
#  28  CNT_PAYMENT                  1297984 non-null  float64
#  29  NAME_YIELD_GROUP             1670214 non-null  object
#  30  PRODUCT_COMBINATION          1669868 non-null  object
#  31  DAYS_FIRST_DRAWING           997149 non-null   float64
#  32  DAYS_FIRST_DUE               997149 non-null   float64
#  33  DAYS_LAST_DUE_1ST_VERSION    997149 non-null   float64
#  34  DAYS_LAST_DUE                997149 non-null   float64
#  35  DAYS_TERMINATION             997149 non-null   float64
#  36  NFLAG_INSURED_ON_APPROVAL    997149 non-null   float64
# dtypes: float64(15), int64(6), object(16)
# memory usage: 471.5+ MB

# %%
df2.NAME_CONTRACT_STATUS.unique()
# Out:
# array(['Approved', 'Refused', 'Canceled', 'Unused offer'], dtype=object)

# %%
sns.countplot(df2.NAME_CONTRACT_STATUS)
plt.xlabel("Contract Status")
plt.ylabel("Count of Contract Status")
plt.title("Distribution of Contract Status")
plt.show()

# %% [markdown]
# ### Identifying missing values and filtering out columns with high missing values

# %%
prev_meta_data=meta_data(df2)
prev_meta_data.reset_index(drop=False).head(20)
# Out:
#                         index    Total  Percent  Unique Data_Type
# 0    RATE_INTEREST_PRIVILEGED  1664263    99.64      25   float64
# 1       RATE_INTEREST_PRIMARY  1664263    99.64     148   float64
# 2           RATE_DOWN_PAYMENT   895844    53.64  207033   float64
# 3            AMT_DOWN_PAYMENT   895844    53.64   29278   float64
# 4             NAME_TYPE_SUITE   820405    49.12       7    object
# 5   NFLAG_INSURED_ON_APPROVAL   673065    40.30       2   float64
# 6          DAYS_FIRST_DRAWING   673065    40.30    2838   float64
# 7              DAYS_FIRST_DUE   673065    40.30    2892   float64
# 8   DAYS_LAST_DUE_1ST_VERSION   673065    40.30    4605   float64
# 9               DAYS_LAST_DUE   673065    40.30    2873   float64
# 10           DAYS_TERMINATION   673065    40.30    2830   float64
# 11            AMT_GOODS_PRICE   385515    23.08   93885   float64
# 12                AMT_ANNUITY   372235    22.29  357959   float64
# 13                CNT_PAYMENT   372230    22.29      49   float64
# 14        PRODUCT_COMBINATION      346     0.02      17    object
# 15               CHANNEL_TYPE        0     0.00       8    object
# 16          NAME_PRODUCT_TYPE        0     0.00       3    object
# 17           NAME_YIELD_GROUP        0     0.00       5    object
# 18           SELLERPLACE_AREA        0     0.00    2097     int64
# 19       NAME_SELLER_INDUSTRY        0     0.00      11    object

# %%
#dropping columns with more than 50% missing values 
cols_to_keep=list(prev_meta_data[(prev_meta_data.Percent<50)].index)
df2=df2[cols_to_keep]
df2.describe()
# Out:
#        NFLAG_INSURED_ON_APPROVAL  DAYS_FIRST_DRAWING  DAYS_FIRST_DUE  DAYS_LAST_DUE_1ST_VERSION  DAYS_LAST_DUE  DAYS_TERMINATION  AMT_GOODS_PRICE   AMT_ANNUITY   CNT_PAYMENT  SELLERPLACE_AREA    SK_ID_PREV    SK_ID_CURR  DAYS_DECISION  NFLAG_LAST_APPL_IN_DAY  HOUR_APPR_PROCESS_START    AMT_CREDIT  AMT_APPLICATION
# count              997149.000000       997149.000000   997149.000000              997149.000000  997149.000000     997149.000000     1.284699e+06  1.297979e+06  1.297984e+06      1.670214e+06  1.670214e+06  1.670214e+06   1.670214e+06            1.670214e+06             1.670214e+06  1.670213e+06     1.670214e+06
# mean                    0.332570       342209.855039    13826.269337               33767.774054   76582.403064      81992.343838     2.278473e+05  1.595512e+04  1.605408e+01      3.139511e+02  1.923089e+06  2.783572e+05  -8.806797e+02            9.964675e-01             1.248418e+01  1.961140e+05     1.752339e+05
# std                     0.471134        88916.115834    72444.869708              106857.034789  149647.415123     153303.516729     3.153966e+05  1.478214e+04  1.456729e+01      7.127443e+03  5.325980e+05  1.028148e+05   7.790997e+02            5.932963e-02             3.334028e+00  3.185746e+05     2.927798e+05
# min                     0.000000        -2922.000000    -2892.000000               -2801.000000   -2889.000000      -2874.000000     0.000000e+00  0.000000e+00  0.000000e+00     -1.000000e+00  1.000001e+06  1.000010e+05  -2.922000e+03            0.000000e+00             0.000000e+00  0.000000e+00     0.000000e+00
# 25%                     0.000000       365243.000000    -1628.000000               -1242.000000   -1314.000000      -1270.000000     5.084100e+04  6.321780e+03  6.000000e+00     -1.000000e+00  1.461857e+06  1.893290e+05  -1.300000e+03            1.000000e+00             1.000000e+01  2.416050e+04     1.872000e+04
# 50%                     0.000000       365243.000000     -831.000000                -361.000000    -537.000000       -499.000000     1.123200e+05  1.125000e+04  1.200000e+01      3.000000e+00  1.923110e+06  2.787145e+05  -5.810000e+02            1.000000e+00             1.200000e+01  8.054100e+04     7.104600e+04
# 75%                     1.000000       365243.000000     -411.000000                 129.000000     -74.000000        -44.000000     2.340000e+05  2.065842e+04  2.400000e+01      8.200000e+01  2.384280e+06  3.675140e+05  -2.800000e+02            1.000000e+00             1.500000e+01  2.164185e+05     1.803600e+05
# max                     1.000000       365243.000000   365243.000000              365243.000000  365243.000000     365243.000000     6.905160e+06  4.180581e+05  8.400000e+01      4.000000e+06  2.845382e+06  4.562550e+05  -1.000000e+00            1.000000e+00             2.300000e+01  6.905160e+06     6.905160e+06

# %%
#Checking columns with very less missing values
low_missing=pd.DataFrame(prev_meta_data[(prev_meta_data.Percent>0.0)&(prev_meta_data.Percent<15)])
low_missing
# Out:
#                      Total  Percent  Unique Data_Type
# PRODUCT_COMBINATION    346     0.02      17    object

# %% [markdown]
# #### we observe there is only one column which is greater than 0 when rounded value is 2

# %%
cols_to_convert=list(prev_meta_data[(prev_meta_data.Unique==2)&((prev_meta_data.Data_Type=="int64")|(prev_meta_data.Data_Type=="float64"))].index)
cols_to_convert
# Out:
# ['NFLAG_INSURED_ON_APPROVAL', 'NFLAG_LAST_APPL_IN_DAY']

# %%
def convert_data(df2, cols_to_convert):
    for y in cols_to_convert:
        df2.loc[:,y].replace((0, 1), ('N', 'Y'), inplace=True)
    return df2
convert_data(df2, cols_to_convert)
df2.dtypes.value_counts()
# Out:
# object     18
# float64    10
# int64       5
# dtype: int64

# %%
approved=df2[df2.NAME_CONTRACT_STATUS=='Approved']
refused=df2[df2.NAME_CONTRACT_STATUS=='Refused']
canceled=df2[df2.NAME_CONTRACT_STATUS=='Canceled']
unused=df2[df2.NAME_CONTRACT_STATUS=='Unused Offer']

# %%
percentage_approved=(len(approved)*100)/len(df2)
percentage_refused=(len(refused)*100)/len(df2)
percentage_canceled=(len(canceled)*100)/len(df2)
percentage_unused=(len(unused)*100)/len(df2)

print("The Percentage of people whose loans have been Approved is:",round(percentage_approved,2),"%")
print("The Percentage of people whose loans have been Refused is:",round(percentage_refused,2),"%")
print("The Percentage of people whose loans have been Canceled is:",round(percentage_canceled,2),"%")
print("The Percentage of people whose loans have been Unused is:",round(percentage_unused,2),"%")
# Out:
# The Percentage of people whose loans have been Approved is: 62.07 %
# The Percentage of people whose loans have been Refused is: 17.4 %
# The Percentage of people whose loans have been Canceled is: 18.94 %
# The Percentage of people whose loans have been Unused is: 0.0 %

# %%
def plot_3charts(var, label_rotation,horizontal_layout):
    if(horizontal_layout):
        fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(15,5))
    else:
        fig, (ax1, ax2, ax3) = plt.subplots(nrows=3, figsize=(15,30))
    
    s1=sns.countplot(ax=ax1,x=refused[var], data=refused, order= refused[var].value_counts().index,)
    ax1.set_title("Refused", fontsize=10)
    ax1.set_xlabel('%s' %var)
    ax1.set_ylabel("Count of Loans")
    if(label_rotation):
        s1.set_xticklabels(s1.get_xticklabels(),rotation=90)
    
    s2=sns.countplot(ax=ax2,x=approved[var], data=approved, order= approved[var].value_counts().index,)
    if(label_rotation):
        s2.set_xticklabels(s2.get_xticklabels(),rotation=90)
    ax2.set_xlabel('%s' %var)
    ax2.set_ylabel("Count of Loans")
    ax2.set_title("Approved", fontsize=10)
    
    
    s3=sns.countplot(ax=ax3,x=canceled[var], data=canceled, order= canceled[var].value_counts().index,)
    ax3.set_title("Canceled", fontsize=10)
    ax3.set_xlabel('%s' %var)
    ax3.set_ylabel("Count of Loans")
    if(label_rotation):
        s3.set_xticklabels(s3.get_xticklabels(),rotation=90)
    plt.show()

# %%
df2.select_dtypes('object').columns
# Out:
# Index(['NAME_TYPE_SUITE', 'NFLAG_INSURED_ON_APPROVAL', 'PRODUCT_COMBINATION', 'CHANNEL_TYPE', 'NAME_PRODUCT_TYPE', 'NAME_YIELD_GROUP', 'NAME_SELLER_INDUSTRY', 'NAME_GOODS_CATEGORY', 'NAME_PORTFOLIO', 'NAME_CLIENT_TYPE', 'CODE_REJECT_REASON', 'NAME_CONTRACT_STATUS', 'NAME_CASH_LOAN_PURPOSE', 'NFLAG_LAST_APPL_IN_DAY', 'FLAG_LAST_APPL_PER_CONTRACT', 'WEEKDAY_APPR_PROCESS_START', 'NAME_CONTRACT_TYPE', 'NAME_PAYMENT_TYPE'], dtype='object')

# %%
plot_3charts('PRODUCT_COMBINATION', label_rotation=True,horizontal_layout=True)

# %% [markdown]
# ##### We observe most number of loans were approved for POS household with interest.
# ##### Most number of refused loans were of Cash X-Sell: Low Product combination
# ##### Most Canceled loans were Cash loans

# %%
plot_3charts('NAME_YIELD_GROUP', label_rotation=True,horizontal_layout=True)

# %% [markdown]
# ##### Most approved loans were from Middle Yield Group
# ##### Most refused loans were from Yield Goups Not specified

# %%
plot_3charts('NAME_PORTFOLIO', label_rotation=True,horizontal_layout=True)

# %% [markdown]
# ##### Most approved loans were POS
# ##### Most refused loans were Cash

# %%
plot_3charts('CHANNEL_TYPE', label_rotation=True,horizontal_layout=True)

# %% [markdown]
# ##### Most approved loans were from Country-wide Channel
# ##### Most refused loans were from Credit and Cash Offices Channel

# %%
plot_3charts('NAME_PRODUCT_TYPE', label_rotation=True,horizontal_layout=True)

# %%
plot_3charts('NAME_PAYMENT_TYPE', label_rotation=True,horizontal_layout=True)

# %%
plot_3charts('NAME_CONTRACT_TYPE', label_rotation=True,horizontal_layout=True)

# %%
plot_3charts('NAME_CLIENT_TYPE', label_rotation=True,horizontal_layout=True)

# %%
sns.countplot(x=approved['NAME_CLIENT_TYPE'], data=df2)

# %% [markdown]
# ## Removing Outliers

# %%
fig, ax = plt.subplots(figsize = (30, 8))
plt.subplot(1, 2, 1)
sns.boxplot(y=approved['AMT_ANNUITY']);
plt.subplot(1, 2, 2)
plt.hist(approved['AMT_ANNUITY'])
plt.title('AMT_ANNUITY')
plt.show()

# %%
approved=approved[approved.AMT_ANNUITY<np.nanpercentile(approved['AMT_ANNUITY'], 99)]
fig, ax = plt.subplots(figsize = (30, 8))
ax.set_title('AMT_ANNUITY boxplot on data within 99 percentile');
plt.subplot(1, 2, 1)
sns.boxplot(y=approved['AMT_ANNUITY']);
plt.subplot(1, 2, 2)
plt.hist(approved['AMT_ANNUITY'])
ax.set_title('AMT_ANNUITY')
# Out:
# Text(0.5, 1.0, 'AMT_ANNUITY')

# %%
fig, ax = plt.subplots(figsize = (30, 8))
plt.subplot(1, 2, 1)
sns.boxplot(y=approved['AMT_CREDIT']);
plt.subplot(1, 2, 2)
plt.hist(approved['AMT_CREDIT'])
plt.title('AMT_CREDIT')
plt.show()

# %%
approved=approved[approved.AMT_CREDIT<np.nanpercentile(approved['AMT_CREDIT'], 90)]
fig, ax = plt.subplots(figsize = (30, 8))
ax.set_title('AMT_CREDIT boxplot on data within 99 percentile');
plt.subplot(1, 2, 1)
sns.boxplot(y=approved['AMT_CREDIT']);
plt.subplot(1, 2, 2)
plt.hist(approved['AMT_CREDIT'])
ax.set_title('AMT_CREDIT')
# Out:
# Text(0.5, 1.0, 'AMT_CREDIT')

# %%
fig, ax = plt.subplots(figsize = (30, 8))
plt.subplot(1, 2, 1)
sns.boxplot(y=approved['AMT_GOODS_PRICE']);
plt.subplot(1, 2, 2)
plt.hist(approved['AMT_GOODS_PRICE'])
plt.title('AMT_GOODS_PRICE')
plt.show()

# %%
approved=approved[approved.AMT_GOODS_PRICE<np.nanpercentile(approved['AMT_GOODS_PRICE'], 90)]
fig, ax = plt.subplots(figsize = (30, 8))
ax.set_title('AMT_GOODS_PRICE boxplot on data within 99 percentile');
plt.subplot(1, 2, 1)
sns.boxplot(y=approved['AMT_GOODS_PRICE']);
plt.subplot(1, 2, 2)
plt.hist(approved['AMT_GOODS_PRICE'])
ax.set_title('AMT_GOODS_PRICE')
# Out:
# Text(0.5, 1.0, 'AMT_GOODS_PRICE')

# %% [markdown]
# ## Bivariate analysis of variables

# %%
cols_approved=['DAYS_TERMINATION', 'DAYS_LAST_DUE', 'DAYS_LAST_DUE_1ST_VERSION', 'DAYS_FIRST_DUE', 'DAYS_FIRST_DRAWING', 'AMT_GOODS_PRICE', 'AMT_ANNUITY', 'CNT_PAYMENT', 'AMT_CREDIT', 'DAYS_DECISION', 'AMT_APPLICATION']

# %%
approved_num=approved[cols_approved]

# %%
cols_refused=['AMT_GOODS_PRICE', 'AMT_ANNUITY', 'CNT_PAYMENT', 'AMT_CREDIT', 'DAYS_DECISION', 'AMT_APPLICATION']
refused_num=refused[cols_refused]

# %%
##calculating correlation for approved
approved_correlation = approved_num.corr()
round(approved_correlation, 3)
# Out:
#                            DAYS_TERMINATION  DAYS_LAST_DUE  DAYS_LAST_DUE_1ST_VERSION  DAYS_FIRST_DUE  DAYS_FIRST_DRAWING  AMT_GOODS_PRICE  AMT_ANNUITY  CNT_PAYMENT  AMT_CREDIT  DAYS_DECISION  AMT_APPLICATION
# DAYS_TERMINATION                      1.000          0.964                      0.467           0.383              -0.346            0.137       -0.059        0.008       0.153          0.477            0.137
# DAYS_LAST_DUE                         0.964          1.000                      0.470           0.431              -0.307            0.136       -0.062        0.009       0.152          0.478            0.136
# DAYS_LAST_DUE_1ST_VERSION             0.467          0.470                      1.000           0.580              -0.739            0.002       -0.184       -0.370       0.006          0.231            0.002
# DAYS_FIRST_DUE                        0.383          0.431                      0.580           1.000              -0.040           -0.034       -0.122       -0.220      -0.030          0.222           -0.034
# DAYS_FIRST_DRAWING                   -0.346         -0.307                     -0.739          -0.040               1.000           -0.024        0.126        0.277      -0.025         -0.155           -0.024
# AMT_GOODS_PRICE                       0.137          0.136                      0.002          -0.034              -0.024            1.000        0.746        0.430       0.970          0.241            1.000
# AMT_ANNUITY                          -0.059         -0.062                     -0.184          -0.122               0.126            0.746        1.000        0.029       0.721          0.170            0.746
# CNT_PAYMENT                           0.008          0.009                     -0.370          -0.220               0.277            0.430        0.029        1.000       0.499          0.045            0.430
# AMT_CREDIT                            0.153          0.152                      0.006          -0.030              -0.025            0.970        0.721        0.499       1.000          0.260            0.970
# DAYS_DECISION                         0.477          0.478                      0.231           0.222              -0.155            0.241        0.170        0.045       0.260          1.000            0.241
# AMT_APPLICATION                       0.137          0.136                      0.002          -0.034              -0.024            1.000        0.746        0.430       0.970          0.241            1.000

# %%
c1=approved_correlation.unstack()
c1.sort_values(ascending=False).drop_duplicates().head(10)
# Out:
# AMT_APPLICATION            AMT_APPLICATION              1.000000
#                            AMT_CREDIT                   0.969696
# DAYS_LAST_DUE              DAYS_TERMINATION             0.964436
# AMT_ANNUITY                AMT_GOODS_PRICE              0.746479
#                            AMT_CREDIT                   0.721244
# DAYS_LAST_DUE_1ST_VERSION  DAYS_FIRST_DUE               0.579953
# AMT_CREDIT                 CNT_PAYMENT                  0.498715
# DAYS_DECISION              DAYS_LAST_DUE                0.478279
# DAYS_TERMINATION           DAYS_DECISION                0.476869
# DAYS_LAST_DUE              DAYS_LAST_DUE_1ST_VERSION    0.470444
# dtype: float64

# %%
c1.sort_values(ascending=False).drop_duplicates().tail(10)
# Out:
# DAYS_TERMINATION           AMT_ANNUITY                 -0.059102
# DAYS_LAST_DUE              AMT_ANNUITY                 -0.062083
# DAYS_FIRST_DUE             AMT_ANNUITY                 -0.121789
# DAYS_DECISION              DAYS_FIRST_DRAWING          -0.154523
# AMT_ANNUITY                DAYS_LAST_DUE_1ST_VERSION   -0.184133
# CNT_PAYMENT                DAYS_FIRST_DUE              -0.220464
# DAYS_LAST_DUE              DAYS_FIRST_DRAWING          -0.306932
# DAYS_FIRST_DRAWING         DAYS_TERMINATION            -0.345834
# DAYS_LAST_DUE_1ST_VERSION  CNT_PAYMENT                 -0.370409
#                            DAYS_FIRST_DRAWING          -0.739219
# dtype: float64

# %% [markdown]
# ## Heat Map for approved correlation

# %%
plt.figure(figsize=(30,20))
sns.heatmap(approved_correlation, cmap="YlGnBu", annot=True)
plt.show()

# %%
##calculating correlation for approved
refused_correlation = refused_num.corr()
round(refused_correlation, 3)
# Out:
#                  AMT_GOODS_PRICE  AMT_ANNUITY  CNT_PAYMENT  AMT_CREDIT  DAYS_DECISION  AMT_APPLICATION
# AMT_GOODS_PRICE            1.000        0.823        0.658       0.992          0.334            1.000
# AMT_ANNUITY                0.823        1.000        0.427       0.820          0.287            0.818
# CNT_PAYMENT                0.658        0.427        1.000       0.677          0.306            0.670
# AMT_CREDIT                 0.992        0.820        0.677       1.000          0.270            0.984
# DAYS_DECISION              0.334        0.287        0.306       0.270          1.000            0.265
# AMT_APPLICATION            1.000        0.818        0.670       0.984          0.265            1.000

# %% [markdown]
# ## Heat map for refused correlation

# %%
plt.figure(figsize=(30,20))
sns.heatmap(refused_correlation, cmap="YlGnBu", annot=True)
plt.show()

# %%
c2=refused_correlation.unstack()
c2.sort_values(ascending=False).drop_duplicates().head(10)
# Out:
# AMT_APPLICATION  AMT_APPLICATION    1.000000
#                  AMT_GOODS_PRICE    0.999699
# AMT_GOODS_PRICE  AMT_CREDIT         0.991777
# AMT_CREDIT       AMT_APPLICATION    0.983785
# AMT_GOODS_PRICE  AMT_ANNUITY        0.822538
# AMT_CREDIT       AMT_ANNUITY        0.819867
# AMT_APPLICATION  AMT_ANNUITY        0.817869
# AMT_CREDIT       CNT_PAYMENT        0.677433
# AMT_APPLICATION  CNT_PAYMENT        0.669782
# CNT_PAYMENT      AMT_GOODS_PRICE    0.658065
# dtype: float64

# %%
c2.sort_values(ascending=False).drop_duplicates().tail(10)
# Out:
# AMT_APPLICATION  AMT_ANNUITY        0.817869
# AMT_CREDIT       CNT_PAYMENT        0.677433
# AMT_APPLICATION  CNT_PAYMENT        0.669782
# CNT_PAYMENT      AMT_GOODS_PRICE    0.658065
#                  AMT_ANNUITY        0.427319
# DAYS_DECISION    AMT_GOODS_PRICE    0.334064
# CNT_PAYMENT      DAYS_DECISION      0.305751
# AMT_ANNUITY      DAYS_DECISION      0.286620
# AMT_CREDIT       DAYS_DECISION      0.270099
# AMT_APPLICATION  DAYS_DECISION      0.264581
# dtype: float64

# %%
def has_terminated(x):
    if x < 0:
        return 'Loan Terminated'
    else:
        return 'Loan Open'
    
approved['CURRENT_STATUS'] = approved['DAYS_TERMINATION'].apply(has_terminated)

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=approved['CURRENT_STATUS'], data=approved)
plt.show()

# %%
new_df= df2.pivot_table(values = 'NAME_CONTRACT_STATUS', index = 'SK_ID_CURR', aggfunc = 'count')
new_df=new_df.reset_index(drop=False)
new_df.rename(columns = {'NAME_CONTRACT_STATUS':'Count of Refused Loans'}, inplace = True)

# %%
merged_df1=pd.merge(new_df, pd.DataFrame(df1[['SK_ID_CURR','TARGET']]), how='inner', on='SK_ID_CURR')

# %%
merged_df1=merged_df1[merged_df1['Count of Refused Loans']!=0]

# %%
merged_df1.head()
# Out:
#    SK_ID_CURR  Count of Refused Loans  TARGET
# 0      100002                       1       1
# 1      100003                       3       0
# 2      100004                       1       0
# 3      100006                       9       0
# 4      100007                       6       0

# %%
merged_df1[merged_df1['TARGET']==0].head()
# Out:
#    SK_ID_CURR  Count of Refused Loans  TARGET
# 1      100003                       3       0
# 2      100004                       1       0
# 3      100006                       9       0
# 4      100007                       6       0
# 5      100008                       5       0

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# **1. Banks should focus more on contract type ‘Student’ ,’pensioner’ and ‘Businessman’ with housing ‘type other
#      than ‘Co-op apartment’ for successful payments.**
#
# **2. Banks should focus less on income type ‘Working’ as they are having most number of unsuccessful payments.**
#
# **3. Also with loan purpose ‘Repair’ is having higher number of unsuccessful payments on time.**
#
# **4. Get as much as clients from housing type ‘With parents’ as they are having least number of unsuccessful payments.**
